# %% [markdown]
# # City Weather
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude).
# * More interestingly is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
import csv

from config import api_key
from citipy import citipy

# %%
output_cities_file = "../output/cities.csv"
output_city_weather_file = "../output/city_weather.csv"

lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ### Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs_zip = []
cities = []
country_codes = []
lat = []
lng = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size= 1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size= 1500)
lat_lngs_zip = list(zip(lats, lngs))

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs_zip:
    city_info = citipy.nearest_city(lat_lng[0], lat_lng[1])
    city = city_info.city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        country_codes.append(city_info.country_code.upper())
        lat.append(round(lat_lng[0],2))
        lng.append(round(lat_lng[1],2))

# %%
# Print the city count to confirm sufficient count
len(cities), len(country_codes), len(lat), len(lng)
# Out:
# (613, 613, 613, 613)

# %%
# create a data frame for the cities
cities_df = pd.DataFrame({"Country": country_codes,
                          "City": cities,
                          "Lat": lat,
                          "Lng": lng})

# # Order the cities by country and city and add an ID
cities_df.sort_values(by=["Country", "City"], inplace=True)
cities_df.sort_values(by=["Country", "City"], inplace=True)
cities_df.reset_index(drop=True, inplace=True)
cities_df = cities_df[["Country", "City", "Lat", "Lng"]]
cities_df.head()
# Out:
#   Country        City    Lat    Lng
# 0      AF     eskasem  37.50  71.64
# 1      AG  codrington  21.61 -54.78
# 2      AN  nieuwpoort  11.54 -68.59
# 3      AO     cabinda  -5.88  11.73
# 4      AO      lucapa  -7.69  20.19

# %%
# Save the city list to a csv file
# create output directory
if not os.path.isdir('../output'):
    os.makedirs('../output')
    
# Output cities data (CSV)
cities_df.to_csv(output_cities_file, index=False, header=True)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
humidity = []
cloudiness = []
max_temperature = []
wind_speed = []
cities_with_weather_data = []
date = []
cities_log = []

# %%
# build OpenWeather API query url to get weather data
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
base_query_url = f"{url}appid={api_key}&units={units}&q="
base_query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=b0dc531704e9525b6dbd0b127eaee094&units=imperial&q='

# %%
# Get weather data from OpenWeather API

title = 'Begining Data Retrieval'
print("\n" + "-" * len(title))
print('Begining Data Retrieval')
print("-" * len(title) + "\n")

# print out starting time
start_utc = time.time()
start_utc_formated = time.gmtime(start_utc)
start_time = time.strftime("%m/%d/%y %H:%M", start_utc_formated)
# start_date = time.strftime("%m/%d/%y", start_utc_formated)
print(f"Started at {start_time} UTC\n")

for index, row in cities_df.iterrows():
    city = row['City']
    try: 
        query_url = base_query_url + city
        response = requests.get(query_url).json()
        
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]['all'])
        max_temperature.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        
        cities_with_weather_data.append(city)
        date.append(int(time.time())) 
        msg = f"Processing city with ID {index} | {city}"
        
    except Exception as e:
        
        if type(e) == KeyError:
            msg = f"...weather info not found for {city}. Skipping..."
        else:
            msg = f"...Other issue for city {city}. Skipping..."
               
    cities_log.append(msg)
    print(msg)

end_utc = time.time()
end_utc_formated = time.gmtime(end_utc)
end_time = time.strftime("%m/%d/%y %H:%M", end_utc_formated)
end_date = time.strftime("%m/%d/%y", end_utc_formated)

duration = round((end_utc - start_utc)/60, 2)

print(f"\nFinished at {end_time} UTC. {len(date)} row of records created")
print(f"Duration: {duration} minutes\n")
# Out:
# -----------------------
# Begining Data Retrieval
# -----------------------
#
# Started at 02/27/19 04:55 UTC
#
# ...weather info not found for eskasem. Skipping...
# Processing city with ID 1 | codrington
# Processing city with ID 2 | nieuwpoort
# Processing city with ID 3 | cabinda
# Processing city with ID 4 | lucapa
# Processing city with ID 5 | namibe
# Processing city with ID 6 | comodoro rivadavia
# Processing city with ID 7 | goya
# Processing city with ID 8 | mar del plata
# Processing city with ID 9 | parana
# Processing city with ID 10 | puerto madryn
# Processing city with ID 11 | rio gallegos
# Processing city with ID 12 | salta
# Processing city with ID 13 | san luis
# Processing city with ID 14 | ushuaia
# Processing city with ID 15 | haag
# Processing city with ID 16 | albany
# Processing city with ID 17 | bowen
# Processing city with ID 18 | broken hill
# Processing city with ID 19 | broome
# Processing city with ID 20 | bundaberg
# Processing city with ID 21 | burnie
# Processing city with ID 22 | busselton
# Processing city with ID 23 | carnarvon
# Processing city with ID 24 | esperance
# Processing city with ID 25 | flinders
# Processing city with ID 26 | forbes
# Processing city with ID 27 | gold coast
# Processing city with ID 28 | hobart
# Processing city with ID 29 | innisfail
# Processing city with ID 30 | karratha
# Processing city with ID 31 | kununurra
# Processing city with ID 32 | launceston
# Processing city with ID 33 | mackay
# Processing city with ID 34 | mildura
# ...weather info not found for milingimbi. Skipping...
# Processing city with ID 36 | mount gambier
# Processing city with ID 37 | mount isa
# Processing city with ID 38 | new norfolk
# ...weather info not found for nguiu. Skipping...
# ...weather info not found for ngukurr. Skipping...
# Processing city with ID 41 | northam
# Processing city with ID 42 | palmerston
# Processing city with ID 43 | port macquarie
# Processing city with ID 44 | portland
# Processing city with ID 45 | roebourne
# Processing city with ID 46 | roma
# Processing city with ID 47 | wonthaggi
# Processing city with ID 48 | yulara
# Processing city with ID 49 | artyom
# Processing city with ID 50 | bathsheba
# Processing city with ID 51 | oistins
# Processing city with ID 52 | kaolinovo
# Processing city with ID 53 | kandi
# Processing city with ID 54 | hamilton
# Processing city with ID 55 | saint george
# Processing city with ID 56 | agudos
# Processing city with ID 57 | alenquer
# Processing city with ID 58 | amapa
# Processing city with ID 59 | aripuana
# Processing city with ID 60 | arraial do cabo
# Processing city with ID 61 | barcelos
# Processing city with ID 62 | bom jardim
# Processing city with ID 63 | carauari
# Processing city with ID 64 | cidreira
# Processing city with ID 65 | cururupu
# Processing city with ID 66 | dom pedrito
# Processing city with ID 67 | floriano
# Processing city with ID 68 | florianopolis
# Processing city with ID 69 | irati
# ...weather info not found for itaobim. Skipping...
# Processing city with ID 71 | laguna
# Processing city with ID 72 | manaus
# Processing city with ID 73 | maragogi
# Processing city with ID 74 | miguelopolis
# Processing city with ID 75 | morros
# Processing city with ID 76 | olinda
# Processing city with ID 77 | posse
# Processing city with ID 78 | rio grande
# Processing city with ID 79 | santa luzia
# Processing city with ID 80 | sao felix do xingu
# Processing city with ID 81 | sao joao da barra
# Processing city with ID 82 | tamandare
# Processing city with ID 83 | vila velha
# Processing city with ID 84 | marsh harbour
# Processing city with ID 85 | damphu
# Processing city with ID 86 | punakha
# ...weather info not found for bokspits. Skipping...
# Processing city with ID 88 | ghanzi
# ...weather info not found for kobojango. Skipping...
# Processing city with ID 90 | shakawe
# Processing city with ID 91 | zlobin
# ...weather info not found for attawapiskat. Skipping...
# Processing city with ID 93 | bathurst
# Processing city with ID 94 | bonavista
# Processing city with ID 95 | cap-aux-meules
# Processing city with ID 96 | chapais
# Processing city with ID 97 | clyde river
# Processing city with ID 98 | dauphin
# Processing city with ID 99 | fort nelson
# Processing city with ID 100 | geraldton
# Processing city with ID 101 | haines junction
# Processing city with ID 102 | havre-saint-pierre
# Processing city with ID 103 | hay river
# Processing city with ID 104 | high level
# Processing city with ID 105 | kapuskasing
# Processing city with ID 106 | matagami
# Processing city with ID 107 | melfort
# Processing city with ID 108 | montague
# Processing city with ID 109 | norman wells
# Processing city with ID 110 | pangnirtung
# Processing city with ID 111 | port hardy
# Processing city with ID 112 | port hawkesbury
# Processing city with ID 113 | prince rupert
# Processing city with ID 114 | saint anthony
# Processing city with ID 115 | saint-augustin
# Processing city with ID 116 | sault sainte marie
# Processing city with ID 117 | shelburne
# Processing city with ID 118 | sioux lookout
# Processing city with ID 119 | thompson
# Processing city with ID 120 | torbay
# Processing city with ID 121 | tuktoyaktuk
# Processing city with ID 122 | ucluelet
# Processing city with ID 123 | vanderhoof
# Processing city with ID 124 | yellowknife
# Processing city with ID 125 | bulungu
# Processing city with ID 126 | isiro
# Processing city with ID 127 | lodja
# Processing city with ID 128 | tshela
# Processing city with ID 129 | bossangoa
# Processing city with ID 130 | sibut
# Processing city with ID 131 | tabou
# Processing city with ID 132 | avarua
# Processing city with ID 133 | antofagasta
# Processing city with ID 134 | castro
# Processing city with ID 135 | chillan
# Processing city with ID 136 | coihaique
# Processing city with ID 137 | copiapo
# Processing city with ID 138 | coquimbo
# Processing city with ID 139 | lebu
# Processing city with ID 140 | ovalle
# Processing city with ID 141 | punta arenas
# Processing city with ID 142 | san antonio
# Processing city with ID 143 | vallenar
# Processing city with ID 144 | aksu
# Processing city with ID 145 | dali
# Processing city with ID 146 | hami
# ...weather info not found for huaidian. Skipping...
# Processing city with ID 148 | huanren
# Processing city with ID 149 | jinchang
# Processing city with ID 150 | jining
# Processing city with ID 151 | lasa
# Processing city with ID 152 | liuzhou
# Processing city with ID 153 | quzhou
# Processing city with ID 154 | shache
# ...weather info not found for wulanhaote. Skipping...
# Processing city with ID 156 | xinyang
# ...weather info not found for yanan. Skipping...
# Processing city with ID 158 | yongan
# Processing city with ID 159 | zhoucheng
# Processing city with ID 160 | albania
# Processing city with ID 161 | cubara
# Processing city with ID 162 | puerto leguizamo
# Processing city with ID 163 | sonson
# Processing city with ID 164 | baracoa
# Processing city with ID 165 | mantua
# Processing city with ID 166 | ponta do sol
# Processing city with ID 167 | santa maria
# Processing city with ID 168 | sao filipe
# Processing city with ID 169 | hannoversch munden
# Processing city with ID 170 | adrar
# Processing city with ID 171 | puerto ayora
# Processing city with ID 172 | san cristobal
# Processing city with ID 173 | barentu
# Processing city with ID 174 | carballo
# Processing city with ID 175 | los llanos de aridane
# Processing city with ID 176 | muros
# Processing city with ID 177 | santa cruz de tenerife
# Processing city with ID 178 | talavera de la reina
# Processing city with ID 179 | asosa
# Processing city with ID 180 | gore
# Processing city with ID 181 | haukipudas
# Processing city with ID 182 | kuusamo
# Processing city with ID 183 | klaksvik
# Processing city with ID 184 | vestmanna
# Processing city with ID 185 | cahors
# Processing city with ID 186 | cognac
# Processing city with ID 187 | dieppe
# Processing city with ID 188 | tarascon
# Processing city with ID 189 | lastoursville
# Processing city with ID 190 | mayumba
# Processing city with ID 191 | brae
# Processing city with ID 192 | llangefni
# Processing city with ID 193 | macclesfield
# Processing city with ID 194 | poole
# Processing city with ID 195 | sandwick
# Processing city with ID 196 | cayenne
# Processing city with ID 197 | iracoubo
# Processing city with ID 198 | takoradi
# ...weather info not found for illoqqortoormiut. Skipping...
# Processing city with ID 200 | ilulissat
# Processing city with ID 201 | kangaatsiaq
# Processing city with ID 202 | nanortalik
# Processing city with ID 203 | narsaq
# Processing city with ID 204 | paamiut
# Processing city with ID 205 | qaanaaq
# Processing city with ID 206 | qasigiannguit
# Processing city with ID 207 | upernavik
# Processing city with ID 208 | saint-francois
# Processing city with ID 209 | mbini
# ...weather info not found for embonas. Skipping...
# Processing city with ID 211 | milesion
# Processing city with ID 212 | pombia
# Processing city with ID 213 | escuintla
# Processing city with ID 214 | korcula
# Processing city with ID 215 | ambon
# Processing city with ID 216 | atambua
# Processing city with ID 217 | banda aceh
# Processing city with ID 218 | baturaja
# ...weather info not found for bengkulu. Skipping...
# Processing city with ID 220 | boyolangu
# Processing city with ID 221 | kefamenanu
# Processing city with ID 222 | kupang
# Processing city with ID 223 | labuhan
# Processing city with ID 224 | langsa
# Processing city with ID 225 | majene
# ...weather info not found for mentok. Skipping...
# Processing city with ID 227 | nabire
# Processing city with ID 228 | padang
# Processing city with ID 229 | pangkalanbuun
# Processing city with ID 230 | pontianak
# Processing city with ID 231 | sibolga
# Processing city with ID 232 | sungairaya
# Processing city with ID 233 | tarakan
# Processing city with ID 234 | teluknaga
# Processing city with ID 235 | tual
# Processing city with ID 236 | dingle
# Processing city with ID 237 | killybegs
# Processing city with ID 238 | letterkenny
# Processing city with ID 239 | arumbavur
# Processing city with ID 240 | chandausi
# Processing city with ID 241 | chanderi
# Processing city with ID 242 | dwarka
# Processing city with ID 243 | hosanagara
# Processing city with ID 244 | kavaratti
# Processing city with ID 245 | madras
# Processing city with ID 246 | malpe
# ...weather info not found for malwan. Skipping...
# ...weather info not found for mormugao. Skipping...
# Processing city with ID 249 | nichlaul
# Processing city with ID 250 | pasighat
# Processing city with ID 251 | tharad
# Processing city with ID 252 | yanam
# Processing city with ID 253 | hit
# Processing city with ID 254 | kazerun
# Processing city with ID 255 | minab
# Processing city with ID 256 | sarakhs
# Processing city with ID 257 | akureyri
# Processing city with ID 258 | grindavik
# Processing city with ID 259 | hofn
# Processing city with ID 260 | husavik
# ...weather info not found for olafsvik. Skipping...
# Processing city with ID 262 | vestmannaeyjar
# Processing city with ID 263 | alghero
# Processing city with ID 264 | pachino
# Processing city with ID 265 | polignano a mare
# Processing city with ID 266 | tarquinia
# Processing city with ID 267 | tortoli
# Processing city with ID 268 | fukue
# Processing city with ID 269 | hasaki
# Processing city with ID 270 | hirara
# Processing city with ID 271 | itoman
# Processing city with ID 272 | iwanai
# Processing city with ID 273 | katsuura
# Processing city with ID 274 | nakamura
# Processing city with ID 275 | naze
# Processing city with ID 276 | nemuro
# Processing city with ID 277 | nishihara
# Processing city with ID 278 | noshiro
# Processing city with ID 279 | shimoda
# ...weather info not found for yomitan. Skipping...
# ...weather info not found for buariki. Skipping...
# Processing city with ID 282 | butaritari
# ...weather info not found for rungata. Skipping...
# ...weather info not found for utiroa. Skipping...
# Processing city with ID 285 | mitsamiouli
# Processing city with ID 286 | seoul
# Processing city with ID 287 | abay
# Processing city with ID 288 | derzhavinsk
# Processing city with ID 289 | shu
# Processing city with ID 290 | zhezkazgan
# Processing city with ID 291 | beruwala
# Processing city with ID 292 | hambantota
# Processing city with ID 293 | kalmunai
# Processing city with ID 294 | trincomalee
# Processing city with ID 295 | harper
# Processing city with ID 296 | darnah
# Processing city with ID 297 | gat
# Processing city with ID 298 | jalu
# Processing city with ID 299 | marzuq
# Processing city with ID 300 | waddan
# Processing city with ID 301 | nador
# ...weather info not found for tarudant. Skipping...
# Processing city with ID 303 | beloha
# Processing city with ID 304 | mahajanga
# Processing city with ID 305 | marovoay
# ...weather info not found for taolanaro. Skipping...
# ...weather info not found for tsihombe. Skipping...
# Processing city with ID 308 | nioro
# Processing city with ID 309 | taoudenni
# Processing city with ID 310 | tessalit
# Processing city with ID 311 | atar
# ...weather info not found for bababe. Skipping...
# Processing city with ID 313 | nouakchott
# Processing city with ID 314 | bambous virieux
# ...weather info not found for grand river south east. Skipping...
# Processing city with ID 316 | mahebourg
# Processing city with ID 317 | souillac
# Processing city with ID 318 | hithadhoo
# Processing city with ID 319 | mahibadhoo
# Processing city with ID 320 | thinadhoo
# Processing city with ID 321 | ugoofaaru
# Processing city with ID 322 | nkhotakota
# Processing city with ID 323 | acapulco
# Processing city with ID 324 | cabo san lucas
# Processing city with ID 325 | constitucion
# Processing city with ID 326 | guerrero negro
# Processing city with ID 327 | ixtapa
# Processing city with ID 328 | lazaro cardenas
# Processing city with ID 329 | pochutla
# Processing city with ID 330 | san patricio
# Processing city with ID 331 | yavaros
# Processing city with ID 332 | kota belud
# Processing city with ID 333 | labuan
# Processing city with ID 334 | lahad datu
# Processing city with ID 335 | angoche
# Processing city with ID 336 | montepuez
# Processing city with ID 337 | henties bay
# Processing city with ID 338 | luderitz
# Processing city with ID 339 | otjimbingwe
# Processing city with ID 340 | walvis bay
# Processing city with ID 341 | bourail
# Processing city with ID 342 | noumea
# Processing city with ID 343 | poum
# Processing city with ID 344 | vao
# Processing city with ID 345 | ouallam
# Processing city with ID 346 | tanout
# Processing city with ID 347 | abonnema
# Processing city with ID 348 | malumfashi
# Processing city with ID 349 | pindiga
# Processing city with ID 350 | yenagoa
# Processing city with ID 351 | santo domingo
# Processing city with ID 352 | siuna
# Processing city with ID 353 | berlevag
# Processing city with ID 354 | bud
# Processing city with ID 355 | karasjok
# Processing city with ID 356 | larsnes
# Processing city with ID 357 | oksfjord
# Processing city with ID 358 | ovre ardal
# Processing city with ID 359 | raudeberg
# Processing city with ID 360 | sorland
# Processing city with ID 361 | alofi
# Processing city with ID 362 | ahipara
# Processing city with ID 363 | bluff
# Processing city with ID 364 | kaitangata
# Processing city with ID 365 | tuatapere
# Processing city with ID 366 | waipawa
# Processing city with ID 367 | ibra
# Processing city with ID 368 | salalah
# Processing city with ID 369 | sur
# ...weather info not found for camana. Skipping...
# Processing city with ID 371 | hualmay
# Processing city with ID 372 | huarmey
# Processing city with ID 373 | los aquijes
# Processing city with ID 374 | nauta
# Processing city with ID 375 | nicolas de pierola
# Processing city with ID 376 | pisco
# Processing city with ID 377 | requena
# Processing city with ID 378 | sechura
# Processing city with ID 379 | tarata
# Processing city with ID 380 | uchiza
# Processing city with ID 381 | atuona
# Processing city with ID 382 | faanui
# Processing city with ID 383 | fare
# Processing city with ID 384 | mataura
# Processing city with ID 385 | rikitea
# Processing city with ID 386 | tautira
# Processing city with ID 387 | vaitape
# ...weather info not found for balimo. Skipping...
# Processing city with ID 389 | daru
# Processing city with ID 390 | kavieng
# Processing city with ID 391 | kimbe
# Processing city with ID 392 | lorengau
# Processing city with ID 393 | vanimo
# Processing city with ID 394 | algeciras
# ...weather info not found for bacuit. Skipping...
# Processing city with ID 396 | callaguip
# Processing city with ID 397 | gigmoto
# Processing city with ID 398 | payo
# Processing city with ID 399 | san policarpo
# Processing city with ID 400 | san vicente
# ...weather info not found for hunza. Skipping...
# Processing city with ID 402 | ormara
# ...weather info not found for angra. Skipping...
# Processing city with ID 404 | camacha
# Processing city with ID 405 | canico
# Processing city with ID 406 | lagoa
# Processing city with ID 407 | praia da vitoria
# Processing city with ID 408 | ribeira grande
# Processing city with ID 409 | vila franca do campo
# Processing city with ID 410 | airai
# Processing city with ID 411 | pozo colorado
# Processing city with ID 412 | khor
# Processing city with ID 413 | le port
# Processing city with ID 414 | saint-denis
# Processing city with ID 415 | saint-joseph
# Processing city with ID 416 | saint-philippe
# Processing city with ID 417 | draguseni
# Processing city with ID 418 | aginskoye
# Processing city with ID 419 | aksarka
# Processing city with ID 420 | almaznyy
# ...weather info not found for amderma. Skipping...
# Processing city with ID 422 | anadyr
# Processing city with ID 423 | arkhangelskoye
# Processing city with ID 424 | batagay
# Processing city with ID 425 | batagay-alyta
# ...weather info not found for belushya guba. Skipping...
# Processing city with ID 427 | beringovskiy
# Processing city with ID 428 | bilibino
# Processing city with ID 429 | bratsk
# Processing city with ID 430 | chernyshevskiy
# Processing city with ID 431 | cherskiy
# ...weather info not found for cheuskiny. Skipping...
# Processing city with ID 433 | chokurdakh
# Processing city with ID 434 | chumikan
# Processing city with ID 435 | dikson
# Processing city with ID 436 | egvekinot
# Processing city with ID 437 | evensk
# Processing city with ID 438 | gornopravdinsk
# Processing city with ID 439 | khani
# Processing city with ID 440 | khatanga
# Processing city with ID 441 | kholtoson
# Processing city with ID 442 | kodinsk
# Processing city with ID 443 | komsomolskiy
# ...weather info not found for krasnoselkup. Skipping...
# Processing city with ID 445 | kropotkin
# Processing city with ID 446 | kysyl-syr
# Processing city with ID 447 | labytnangi
# Processing city with ID 448 | lavrentiya
# Processing city with ID 449 | leningradskiy
# Processing city with ID 450 | mama
# Processing city with ID 451 | milyutinskaya
# Processing city with ID 452 | mochalishche
# Processing city with ID 453 | muravlenko
# ...weather info not found for mys shmidta. Skipping...
# Processing city with ID 455 | navashino
# Processing city with ID 456 | nevelsk
# Processing city with ID 457 | nikolskoye
# ...weather info not found for nizhneyansk. Skipping...
# Processing city with ID 459 | okha
# Processing city with ID 460 | ossora
# Processing city with ID 461 | ostrovnoy
# Processing city with ID 462 | ous
# Processing city with ID 463 | palana
# Processing city with ID 464 | pechory
# Processing city with ID 465 | pevek
# Processing city with ID 466 | pokrovsk
# Processing city with ID 467 | proletariy
# Processing city with ID 468 | provideniya
# Processing city with ID 469 | rudnogorsk
# Processing city with ID 470 | saskylakh
# Processing city with ID 471 | semikarakorsk
# ...weather info not found for sentyabrskiy. Skipping...
# Processing city with ID 473 | severo-kurilsk
# Processing city with ID 474 | sovetskiy
# Processing city with ID 475 | sovetskoye
# Processing city with ID 476 | spornoye
# Processing city with ID 477 | srednekolymsk
# Processing city with ID 478 | strezhevoy
# Processing city with ID 479 | suntar
# Processing city with ID 480 | synya
# Processing city with ID 481 | talakan
# Processing city with ID 482 | talnakh
# Processing city with ID 483 | tazovskiy
# Processing city with ID 484 | teguldet
# Processing city with ID 485 | terney
# Processing city with ID 486 | tigil
# Processing city with ID 487 | tiksi
# Processing city with ID 488 | tilichiki
# ...weather info not found for tumannyy. Skipping...
# Processing city with ID 490 | tura
# Processing city with ID 491 | turukhansk
# Processing city with ID 492 | urengoy
# Processing city with ID 493 | ust-nera
# Processing city with ID 494 | vanavara
# Processing city with ID 495 | verkhnetulomskiy
# Processing city with ID 496 | verkhnevilyuysk
# Processing city with ID 497 | vilyuysk
# Processing city with ID 498 | vokhma
# Processing city with ID 499 | volot
# Processing city with ID 500 | vyartsilya
# ...weather info not found for yanchukan. Skipping...
# Processing city with ID 502 | yar-sale
# Processing city with ID 503 | yashalta
# ...weather info not found for yuzhno-yeniseyskiy. Skipping...
# Processing city with ID 505 | zyryanka
# Processing city with ID 506 | abha
# Processing city with ID 507 | buraydah
# Processing city with ID 508 | jizan
# ...weather info not found for sakakah. Skipping...
# Processing city with ID 510 | tabuk
# Processing city with ID 511 | honiara
# Processing city with ID 512 | lata
# Processing city with ID 513 | victoria
# Processing city with ID 514 | ler
# Processing city with ID 515 | marawi
# Processing city with ID 516 | kungalv
# Processing city with ID 517 | georgetown
# Processing city with ID 518 | jamestown
# Processing city with ID 519 | spodnja idrija
# Processing city with ID 520 | zrece
# ...weather info not found for barentsburg. Skipping...
# Processing city with ID 522 | longyearbyen
# Processing city with ID 523 | bonthe
# Processing city with ID 524 | goderich
# Processing city with ID 525 | bandarbeyla
# Processing city with ID 526 | bosaso
# Processing city with ID 527 | eyl
# Processing city with ID 528 | hobyo
# Processing city with ID 529 | mogadishu
# Processing city with ID 530 | brokopondo
# Processing city with ID 531 | acajutla
# Processing city with ID 532 | aleppo
# Processing city with ID 533 | cockburn town
# Processing city with ID 534 | faya
# Processing city with ID 535 | kathu
# Processing city with ID 536 | yovon
# Processing city with ID 537 | vaini
# Processing city with ID 538 | develi
# Processing city with ID 539 | mus
# Processing city with ID 540 | samsun
# Processing city with ID 541 | scarborough
# ...weather info not found for asau. Skipping...
# Processing city with ID 543 | bungu
# Processing city with ID 544 | kakonko
# Processing city with ID 545 | karema
# Processing city with ID 546 | morogoro
# Processing city with ID 547 | dovbysh
# Processing city with ID 548 | klenovyy
# Processing city with ID 549 | adjumani
# Processing city with ID 550 | barrow
# Processing city with ID 551 | bethel
# Processing city with ID 552 | college
# Processing city with ID 553 | corning
# Processing city with ID 554 | edinburg
# Processing city with ID 555 | elko
# Processing city with ID 556 | englewood
# Processing city with ID 557 | evans
# Processing city with ID 558 | fortuna
# Processing city with ID 559 | garden city
# Processing city with ID 560 | grand island
# Processing city with ID 561 | guymon
# Processing city with ID 562 | havre
# Processing city with ID 563 | hilo
# Processing city with ID 564 | isla vista
# Processing city with ID 565 | juneau
# Processing city with ID 566 | kahului
# Processing city with ID 567 | kapaa
# Processing city with ID 568 | kenai
# Processing city with ID 569 | kodiak
# Processing city with ID 570 | lompoc
# Processing city with ID 571 | makakilo city
# Processing city with ID 572 | marion
# Processing city with ID 573 | nanakuli
# Processing city with ID 574 | nantucket
# Processing city with ID 575 | nome
# Processing city with ID 576 | north bend
# Processing city with ID 577 | pacific grove
# Processing city with ID 578 | pueblo
# Processing city with ID 579 | raymondville
# Processing city with ID 580 | spring valley
# Processing city with ID 581 | starkville
# Processing city with ID 582 | sumter
# Processing city with ID 583 | uvalde
# Processing city with ID 584 | vidalia
# Processing city with ID 585 | watertown
# Processing city with ID 586 | wilmington
# Processing city with ID 587 | chuy
# Processing city with ID 588 | rocha
# Processing city with ID 589 | road town
# ...weather info not found for da nang. Skipping...
# Processing city with ID 591 | lao cai
# ...weather info not found for qui nhon. Skipping...
# Processing city with ID 593 | thanh hoa
# Processing city with ID 594 | isangel
# ...weather info not found for falealupo. Skipping...
# ...weather info not found for saleaula. Skipping...
# ...weather info not found for samusu. Skipping...
# ...weather info not found for satitoa. Skipping...
# Processing city with ID 599 | bredasdorp
# Processing city with ID 600 | cape town
# Processing city with ID 601 | east london
# Processing city with ID 602 | elliot
# Processing city with ID 603 | fort beaufort
# Processing city with ID 604 | hermanus
# Processing city with ID 605 | kruisfontein
# Processing city with ID 606 | margate
# Processing city with ID 607 | port alfred
# Processing city with ID 608 | port elizabeth
# Processing city with ID 609 | richards bay
# Processing city with ID 610 | saldanha
# ...weather info not found for umzimvubu. Skipping...
# Processing city with ID 612 | mansa
#
# Finished at 02/27/19 05:00 UTC. 561 row of records created
# Duration: 5.04 minutes

# %%
# Double check weather info was retraved for over 500 cities
len(humidity), len(cloudiness), len(max_temperature), len(wind_speed), len(cities_log)
# Out:
# (561, 561, 561, 561, 613)

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a data frame with the weather info
weather_df = pd.DataFrame({
    "City": cities_with_weather_data,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Max Temp": max_temperature,
    "Wind Speed": wind_speed,
    "Date": date
})
weather_df.head()
# Out:
#          City  Humidity  Cloudiness  Max Temp  Wind Speed        Date
# 0  codrington        44          75     82.40       11.41  1551243318
# 1  nieuwpoort        93           0     46.40        3.36  1551243319
# 2     cabinda       100          76     78.48        5.26  1551243319
# 3      lucapa        99          88     69.48        3.98  1551243319
# 4      namibe       100          92     76.14        1.97  1551243321

# %%
# merge weather data frame with city data frame
weather_with_country_df = pd.merge(weather_df, cities_df, on="City")
weather_with_country_df.head()
# Out:
#          City  Humidity  Cloudiness  Max Temp  Wind Speed        Date Country  \
# 0  codrington        44          75     82.40       11.41  1551243318      AG
# 1  nieuwpoort        93           0     46.40        3.36  1551243319      AN
# 2     cabinda       100          76     78.48        5.26  1551243319      AO
# 3      lucapa        99          88     69.48        3.98  1551243319      AO
# 4      namibe       100          92     76.14        1.97  1551243321      AO
#
#      Lat    Lng
# 0  21.61 -54.78
# 1  11.54 -68.59
# 2  -5.88  11.73
# 3  -7.69  20.19
# 4 -20.25   4.03

# %%
# Re-order the columns
weather_with_country_df = weather_with_country_df[["City", "Cloudiness", "Country", "Date", "Humidity", "Lat", "Lng", "Max Temp", "Wind Speed"]]
weather_with_country_df.head()
# Out:
#          City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 0  codrington          75      AG  1551243318        44  21.61 -54.78
# 1  nieuwpoort           0      AN  1551243319        93  11.54 -68.59
# 2     cabinda          76      AO  1551243319       100  -5.88  11.73
# 3      lucapa          88      AO  1551243319        99  -7.69  20.19
# 4      namibe          92      AO  1551243321       100 -20.25   4.03
#
#    Max Temp  Wind Speed
# 0     82.40       11.41
# 1     46.40        3.36
# 2     78.48        5.26
# 3     69.48        3.98
# 4     76.14        1.97

# %%
# Output city weather data (CSV)
weather_with_country_df.to_csv(output_city_weather_file, index=False, header=True)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
# Organize data for plotting
terms = [["Max Temperature", "F"], ["Humidity", " (%)"],[ "Cloudiness", " (%)"], ["Wind Speed", " (mph)"]]
color = '#1177AA'

# %%
# Use subplot to plot the charts
for term in terms: 
    fig = plt.figure()
    ax = fig.add_subplot(1,1,1)
        
    # Set x limit, y limit
    ax.set_xlim(-90, 90)
    if term[0] == "Wind Speed":
        ax.set_ylim(-2, 35)
    else:
        ax.set_ylim(-10, 110)
    
    # Set title, xlabel, ylabel, and grid
    ax.set_title(f"City Latitute vs {term[0]} ({end_date})")
    ax.set_xlabel(f"Latitude")
    ax.set_ylabel(f"{term[0]} {term[1]}")
    plt.grid(True)
       
    # plot
    if term[0] == "Max Temperature":
        filename = "max_temp"
        ax.scatter(weather_with_country_df["Lat"], weather_with_country_df["Max Temp"], marker="o", facecolors=color, edgecolors="black", alpha=0.75)
    else:
        filename = term[0].lower()
        ax.scatter(weather_with_country_df["Lat"], weather_with_country_df[term[0]], marker="o", facecolors=color, edgecolors="black", alpha=0.75)
    
    # Save plot to file
    filename = filename + ".png"
    file_path = f"../output/{filename}"
    plt.savefig(file_path)
    plt.show()
